# %%
# relative import
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from src.buses.reportcard_helpers import *

# %%
# test using the 80Mb 119 database from June 2018
source = 'nj'
stop_report = 30189 # webster and congress
route_report = 119

# %% [markdown]
# ### debugging parse_route_xml

# %%
# alex original

import os
import datetime
import xml.etree.ElementTree

# API like: https://github.com/harperreed/transitapi/wiki/Unofficial-Bustracker-API

_sources = {
  'nj': 'http://mybusnow.njtransit.com/bustime/map/'
}

_api = {
  'all_buses': 'getBusesForRouteAll.jsp',
  'routes': 'getRoutePoints.jsp',
  'pattern_points': 'getPatternPoints.jsp',
  'stop_predictions': 'getStopPredictions.jsp',
  'bus_predictions': 'getBusPredictions.jsp',
  'buses_for_route': 'getBusesForRoute.jsp',
  'schedules': 'schedules.jsp',
  'time_and_temp': 'getTimeAndTemp.jsp',
  'route_directions_xml':  'routeDirectionStopAsXML',
}

# parsers done for all_buses, routes, stop_predictions
# ignored: time_and_temp
# not available / not fully documented: schedules (not sure what the right kwargs are, agency=1 & route=87 ?)


def _gen_command(source, func, **kwargs):
    result = _sources[source] + _api[func]
    params = ''
    for k, v in kwargs.items():
        params = params + k + '=' + str(v) + '&'
    if params:
        result += '?' + params[:-1]
    return result

def _cond_get_single(tree, key, default=''):
    res = tree.find(key)
    if res is not None:
        return res.text 
    return default

class KeyValueData:
    def __init__(self, **kwargs):
        self.name = 'KeyValueData'
        for k, v in kwargs.items():
            setattr(self, k, v)

    def add_kv(self, key, value):
        setattr(self, key, value)

    def __repr__(self):
        line = []
        for prop, value in vars(self).iteritems():
            line.append((prop, value))
        line.sort(key=lambda x: x[0])
        out_string = ' '.join([k + '=' + str(v) for k, v in line])
        return self.name + '[%s]' % out_string

class Route(KeyValueData):

    class Path(KeyValueData):
        def __init__(self):
            KeyValueData.__init__(self)
            self.name = 'Path'
            self.points = []
            self.id = ''
            self.d = ''
            self.dd = ''

    class Point:
        def __init__(self):
            self.lat = ''
            self.lon = ''
            self.d = ''

    class Stop:
        def __init__(self):
            self.identity = ''
            self.st = ''
            self.lat = ''
            self.lon = ''
            self.d = ''

    def __init__(self):
        KeyValueData.__init__(self)
        self.name = 'route'
        self.identity = ''
        self.paths = []


def parse_route_xml(data):

    routes = list()

    route = Route()

    e = xml.etree.ElementTree.fromstring(data)
    for child in e.getchildren():

        if len(child.getchildren()) == 0:
            if child.tag == 'id':
                route.identity = child.text
            else:
                route.add_kv(child.tag, child.text)

        if child.tag == 'pas':

            for pa in child.findall('pa'):

                path = Route.Path()

                for path_child in pa.getchildren():
                    if len(path_child.getchildren()) == 0:
                        if path_child.tag == 'id':
                            path.id = path_child.text
                        elif path_child.tag == 'd':
                            path.d = path_child.text
                        elif path_child.tag == 'dd':
                            path.dd = path_child.text
                        else:
                            path.add_kv(path_child.tag, path_child.text)
                    elif path_child.tag == 'pt':
                        pt = path_child
                        stop = False
                        for bs in pt.findall('bs'):
                            stop = True
                            _stop_id = _cond_get_single(bs, 'id')
                            _stop_st = _cond_get_single(bs, 'st')
                            break

                        p = None
                        if not stop:
                            p = Route.Point()
                        else:
                            p = Route.Stop()
                            p.identity = _stop_id
                            p.st = _stop_st

                        p.d = path.d
                        p.lat = _cond_get_single(pt, 'lat')
                        p.lon = _cond_get_single(pt, 'lon')

                        path.points.append(p) # <------ dont append to same list each time

                route.paths.append(path)

                routes.append(route) # is this the change that broke stopwatcher? used to just be routes.append (route)
                # how can i change the waypoint map thing so this doesnt have to change, or change stopwatcher...

            break

    return routes

def get_xml_data(source, function, **kwargs):
    import urllib2
    data = urllib2.urlopen(_gen_command(source, function, **kwargs)).read()
    return data

# %%
# what it outputs
routes=parse_route_xml(get_xml_data(source, 'routes', route=route_report))
routes
# Out:
# /Users/anthonytownsend/anaconda2/envs/buswatcher/lib/python2.7/site-packages/ipykernel/__main__.py:101: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# /Users/anthonytownsend/anaconda2/envs/buswatcher/lib/python2.7/site-packages/ipykernel/__main__.py:103: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# /Users/anthonytownsend/anaconda2/envs/buswatcher/lib/python2.7/site-packages/ipykernel/__main__.py:115: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# /Users/anthonytownsend/anaconda2/envs/buswatcher/lib/python2.7/site-packages/ipykernel/__main__.py:116: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# [route[c=#ff3399 displayDesignator=119 identity=119 name=route nm=119 Bayonne-Jersey City-NY paths=[Path[d=Bayonne dd=Bayonne directionRtpiFeedName=None id=1860 l=72312.0 name=Path points=[<__main__.Stop instance at 0x10cb19440>, <__main__.Point instance at 0x10cb19518>, <__main__.Point instance at 0x10cb195a8>, <__main__.Point instance at 0x10cb195f0>, <__main__.Point instance at 0x10cb19680>, <__main__.Point instance at 0x10cb19710>, <__main__.Point instance at 0x10cb197a0>, <__main__.Point instance at 0x10cb19830>, <__main__.Point instance at 0x10cb198c0>, <__main__.Point instance at 0x10cb19950>, <__main__.Point instance at 0x10cb199e0>, <__main__.Point instance at 0x10cb19a70>, <__main__.Point instance at 0x10cb19b00>, <__main__.Point instance at 0x10cb19b90>, <__main__.Point instance at 0x10cb19c20>, <__main__.Point instance at 0x10cb19cb0>, <__main__.Point instance at 0x10cb19d40>, <__main__.Point instance at 0x10cb19dd0>, <__main__.Point instance at 0x10cb19e60>, <__main__.Point instance at 0x10cb19ef0>, <__main__.Point instance at 0x10cb19f80>, <__main__.Point instance at 0x10cb20050>, <__main__.Point instance at 0x10cb200e0>, <__main__.Point instance at 0x10cb20170>, <__main__.Point instance at 0x10cb20200>, <__main__.Point instance at 0x10cb20290>, <__main__.Point instance at 0x10cb20320>, <__main__.Point instance at 0x10cb203b0>, <__main__.Point instance at 0x10cb20440>, <__main__.Point instance at 0x10cb204d0>, <__main__.Point instance at 0x10cb20560>, <__main__.Point instance at 0x10cb205f0>, <__main__.Point instance at 0x10cb20680>, <__main__.Point instance at 0x10cb20710>, <__main__.Point instance at 0x10cb207a0>, <__main__.Point instance at 0x10cb20830>, <__main__.Point instance at 0x10cb208c0>, <__main__.Point instance at 0x10cb20950>, <__main__.Point instance at 0x10cb209e0>, <__main__.Point instance at 0x10cb20a70>, <__main__.Point instance at 0x10cb20b00>, <__main__.Point instance at 0x10cb20b90>, <__main__.Point instance at 0x10cb20c20>, <__main__.Point instance at 0x10cb20cb0>, <__main__.Point instance at 0x10cb20d40>, <__main__.Point instance at 0x10cb20dd0>, <__main__.Point instance at 0x10cb20e60>, <__main__.Point instance at 0x10cb20ef0>, <__main__.Point instance at 0x10cb20f80>, <__main__.Point instance at 0x10cb23050>, <__main__.Point instance at 0x10cb230e0>, <__main__.Stop instance at 0x10cb23170>, <__main__.Point instance at 0x10cb23200>, <__main__.Point instance at 0x10cb23290>, <__main__
Point instance at 0x10cb3a1b8>, <__main__.Stop instance at 0x10cb3a200>, <__main__.Point instance at 0x10cb3a248>, <__main__.Point instance at 0x10cb3a290>, <__main__.Stop instance at 0x10cb3a2d8>, <__main__.Point instance at 0x10cb3a320>, <__main__.Point instance at 0x10cb3a368>, <__main__.Point instance at 0x10cb3a3b0>, <__main__.Point instance at 0x10cb3a3f8>, <__main__.Stop instance at 0x10cb3a440>, <__main__.Point instance at 0x10cb3a488>, <__main__.Stop instance at 0x10cb3a4d0>, <__main__.Point instance at 0x10cb3a518>, <__main__.Point instance at 0x10cb3a560>, <__main__.Point instance at 0x10cb3a5a8>, <__main__.Point instance at 0x10cb3a5f0>, <__main__.Stop instance at 0x10cb3a638>, <__main__.Point instance at 0x10cb3a680>, <__main__.Point instance at 0x10cb3a6c8>, <__main__.Stop instance at 0x10cb3a710>, <__main__.Point instance at 0x10cb3a758>, <__main__.Point instance at 0x10cb3a7a0>, <__main__.Stop instance at 0x10cb3a7e8>, <__main__.Point instance at 0x10cb3a830>, <__main__.Point instance at 0x10cb3a878>, <__main__.Stop instance at 0x10cb3a8c0>, <__main__.Point instance at 0x10cb3a908>, <__main__.Point instance at 0x10cb3a950>, <__main__.Stop instance at 0x10cb3a998>, <__main__.Point instance at 0x10cb3a9e0>, <__main__.Point instance at 0x10cb3aa28>, <__main__.Stop instance at 0x10cb3aa70>, <__main__.Point instance at 0x10cb3aab8>, <__main__.Stop instance at 0x10cb3ab00>, <__main__.Point instance at 0x10cb3ab48>, <_ ...

# %%
print "number of routes", len(routes)
for route in routes:
    print "number of paths", len(route.paths)
    for p in route.paths:
        # print p.d
        print "number of points", len(p.points)
        for p in p.points:
            if isinstance(p, Route.Stop):
                print p.st
            else:
                print '-',
# Out:
# number of routes 2
# number of paths 2
# number of points 241
# PORT AUTHORITY BUS TERMINAL
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - WILLOW AVE + 19TH ST
# - - - - WILLOW AVE + 15TH ST
# CONGRESS ST + PALISADE AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + CENTRAL AVE
# - - CENTRAL AVE + SOUTH ST
# CENTRAL AVE + THORNE ST
# CENTRAL AVE + BOWERS ST
# CENTRAL AVE + GRIFFITH ST
# CENTRAL AVE + HUTTON ST
# CENTRAL AVE + SHERMAN PL
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + BOOREAM AVE
# CENTRAL AVE + PERSHING PLAZA
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + LAIDLAW AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + SAINT PAULS AVE
# - CENTRAL AVE + HOBOKEN AVE
# - HOBOKEN AVE + SUMMIT AVE
# - SUMMIT AVE + PAVONIA AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - - - - - - - - - - - SIP AVE + TONNELLE AVE
# - JFK BLVD + SIP AVE
# - - - - JFK BLVD + STUYVESANT AVE
# - JFK BLVD + HIGHLAND AVE
# - JFK BLVD + MONTGOMERY ST
# - - - - - - JFK BLVD + DUNCAN AVE
# - - JFK BLVD + KENSINGTON AVE
# - - JFK BLVD + BELMONT AVENUE
# - JFK BLVD + BENTLEY AVE
# - - - JFK BLVD + COMMUNIPAW AVE
# - JFK BLVD + OXFORD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - - JFK BLVD + BOYD AVE
# - JFK BLVD + EGE AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + BROADMAN PKWY
# JFK BLVD + BAYVIEW AVE
# JFK BLVD + AUDUBON AVE
# JFK BLVD + STEGMAN PKWY
# - - JFK BLVD + VAN HOUTEN AVE
# - - - - - - JFK BLVD + WOODLAWN AVE
# - - JFK BLVD + VAN NOSTRAND AVE
# - - - - JFK BLVD + WADE ST
# - JFK BLVD + MCADOO AVENUE
# - - - JFK BLVD + DANFORTH AVE
# - JFK BLVD + GREENVILLE AVE
# - - - JFK BLVD + PEARSALL AVE
# - JFK BLVD + WINFIELD AVE
# - JFK BLVD + GATES AVE
# JFK BLVD + PAMRAPO AVE
# - - - - JFK BLVD + 63RD ST
# JFK BLVD + 57TH ST
# - JFK BLVD + 54TH ST
# - JFK BLVD + 52ND ST
# - JFK BLVD + 48TH ST
# JFK BLVD + 46TH ST
# JFK BLVD + 44TH ST
# JFK BLVD + 42ND ST
# JFK BLVD + DILLON DR
# - JFK BLVD + 37TH ST
# - - - - - - JFK BLVD + 35TH ST
# JFK BLVD + 33RD ST
# - - JFK BLVD + 30TH ST
# - JFK BLVD + 27TH ST
# JFK BLVD + 25TH ST
# JFK BLVD + 23RD ST
# JFK BLVD + 19TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 8TH ST
# - - - - - - JFK BLVD + W 6TH STREET
# - - JFK BLVD + W 4TH STREET
# JFK BLVD + 2ND ST
# number of points 226
# JFK BLVD + 3RD ST
# - JFK BLVD + 4TH ST
# - - - - JFK BLVD + W 7TH STREET
# - - - - - - JFK BLVD + 8TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 14TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + ANDREW ST
# JFK BLVD + 19TH ST
# JFK BLVD + 21ST ST
# JFK BLVD + 23RD ST
# JFK BLVD + 27TH ST
# JFK BLVD + 30TH ST
# JFK BLVD + 32ND ST
# JFK BLVD + 34TH ST
# - - - - - - - - JFK BLVD + 38 TH ST
# JFK BLVD + 39TH ST
# JFK BLVD + DELVIN DR
# JFK BLVD + 44TH ST
# JFK BLVD + 48TH ST
# JFK BLVD + 50TH ST
# JFK BLVD + 52ND ST
# JFK BLVD + 54TH ST
# JFK BLVD + 57TH ST
# JFK BLVD + 58TH ST
# - - JFK BLVD + 63RD ST
# JFK BLVD + GATES AVE
# JFK BLVD + WINFIELD AVE
# JFK BLVD + PEARSALL AVE
# - - - - JFK BLVD + GREENVILLE AVE
# - JFK BLVD + DANFORTH AVE
# - - JFK BLVD + MCADOO AVE
# - - JFK BLVD + WADE ST
# - - - - JFK BLVD + FOWLER AVE
# - JFK BLVD + WOODLAWN AVE
# - - - - JFK BLVD + DWIGHT ST
# - - JFK BLVD + AUDUBON AVE
# - - JFK BLVD + BAYVIEW AVENUE
# - - JFK BLVD + BROADMAN PKWY
# - - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + EGE AVE
# - - JFK BLVD + BOYD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - JFK BLVD + CLINTON AVE
# - JFK BLVD + COMMUNIPAW AVE
# - - JFK BLVD + BENTLEY AVE
# - - - - JFK BLVD + KENSINGTON AVE
# - JFK BLVD + JEWETT AVE
# - - JFK BLVD + DUNCAN AVE
# - - - - JFK BLVD + MONTGOMERY ST
# - - JFK BLVD + GLENWOOD AVE
# - - JFK BLVD + STUYVESANT AVE
# - - - - JFK BLVD + SIP AVE
# - SIP AVE + TONNELLE AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - HOBOKEN AVE + SUMMIT AVE
# - - CENTRAL AVE + HOBOKEN AVE
# - - CENTRAL AVE + SAINT PAULS AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + RESERVOIR AVE
# CENTRAL AVE + BOORAEM AVE
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + FRANKLIN ST
# - CENTRAL AVE + HUTTON ST
# CENTRAL AVE + GRIFFITH ST
# - CENTRAL AVE + BOWERS ST
# CENTRAL AVE + CHARLES ST
# CENTRAL AVE + SOUTH ST
# CENTRAL AVE + CONGRESS ST
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + PALISADE AVE
# - CONGRESS ST HBLR STATION
# - S WING VIADUCT + PATERSON PLANK ROAD
# - - - - - - - - - - WILLOW AVE + 15TH ST
# WILLOW AVE + 19TH ST
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - PORT AUTHORITY BUS TERMINAL + EAST END ARRIVAL
# number of paths 2
# number of points 241
# PORT AUTHORITY BUS TERMINAL
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - WILLOW AVE + 19TH ST
# - - - - WILLOW AVE + 15TH ST
# CONGRESS ST + PALISADE AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + CENTRAL AVE
# - - CENTRAL AVE + SOUTH ST
# CENTRAL AVE + THORNE ST
# CENTRAL AVE + BOWERS ST
# CENTRAL AVE + GRIFFITH ST
# CENTRAL AVE + HUTTON ST
# CENTRAL AVE + SHERMAN PL
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + BOOREAM AVE
# CENTRAL AVE + PERSHING PLAZA
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + LAIDLAW AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + SAINT PAULS AVE
# - CENTRAL AVE + HOBOKEN AVE
# - HOBOKEN AVE + SUMMIT AVE
# - SUMMIT AVE + PAVONIA AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - - - - - - - - - - - SIP AVE + TONNELLE AVE
# - JFK BLVD + SIP AVE
# - - - - JFK BLVD + STUYVESANT AVE
# - JFK BLVD + HIGHLAND AVE
# - JFK BLVD + MONTGOMERY ST
# - - - - - - JFK BLVD + DUNCAN AVE
# - - JFK BLVD + KENSINGTON AVE
# - - JFK BLVD + BELMONT AVENUE
# - JFK BLVD + BENTLEY AVE
# - - - JFK BLVD + COMMUNIPAW AVE
# - JFK BLVD + OXFORD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - - JFK BLVD + BOYD AVE
# - JFK BLVD + EGE AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + BROADMAN PKWY
# JFK BLVD + BAYVIEW AVE
# JFK BLVD + AUDUBON AVE
# JFK BLVD + STEGMAN PKWY
# - - JFK BLVD + VAN HOUTEN AVE
# - - - - - - JFK BLVD + WOODLAWN AVE
# - - JFK BLVD + VAN NOSTRAND AVE
# - - - - JFK BLVD + WADE ST
# - JFK BLVD + MCADOO AVENUE
# - - - JFK BLVD + DANFORTH AVE
# - JFK BLVD + GREENVILLE AVE
# - - - JFK BLVD + PEARSALL AVE
# - JFK BLVD + WINFIELD AVE
# - JFK BLVD + GATES AVE
# JFK BLVD + PAMRAPO AVE
# - - - - JFK BLVD + 63RD ST
# JFK BLVD + 57TH ST
# - JFK BLVD + 54TH ST
# - JFK BLVD + 52ND ST
# - JFK BLVD + 48TH ST
# JFK BLVD + 46TH ST
# JFK BLVD + 44TH ST
# JFK BLVD + 42ND ST
# JFK BLVD + DILLON DR
# - JFK BLVD + 37TH ST
# - - - - - - JFK BLVD + 35TH ST
# JFK BLVD + 33RD ST
# - - JFK BLVD + 30TH ST
# - JFK BLVD + 27TH ST
# JFK BLVD + 25TH ST
# JFK BLVD + 23RD ST
# JFK BLVD + 19TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 8TH ST
# - - - - - - JFK BLVD + W 6TH STREET
# - - JFK BLVD + W 4TH STREET
# JFK BLVD + 2ND ST
# number of points 226
# JFK BLVD + 3RD ST
# - JFK BLVD + 4TH ST
# - - - - JFK BLVD + W 7TH STREET
# - - - - - - JFK BLVD + 8TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 14TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + ANDREW ST
# JFK BLVD + 19TH ST
# JFK BLVD + 21ST ST
# JFK BLVD + 23RD ST
# JFK BLVD + 27TH ST
# JFK BLVD + 30TH ST
# JFK BLVD + 32ND ST
# JFK BLVD + 34TH ST
# - - - - - - - - JFK BLVD + 38 TH ST
# JFK BLVD + 39TH ST
# JFK BLVD + DELVIN DR
# JFK BLVD + 44TH ST
# JFK BLVD + 48TH ST
# JFK BLVD + 50TH ST
# JFK BLVD + 52ND ST
# JFK BLVD + 54TH ST
# JFK BLVD + 57TH ST
# JFK BLVD + 58TH ST
# - - JFK BLVD + 63RD ST
# JFK BLVD + GATES AVE
# JFK BLVD + WINFIELD AVE
# JFK BLVD + PEARSALL AVE
# - - - - JFK BLVD + GREENVILLE AVE
# - JFK BLVD + DANFORTH AVE
# - - JFK BLVD + MCADOO AVE
# - - JFK BLVD + WADE ST
# - - - - JFK BLVD + FOWLER AVE
# - JFK BLVD + WOODLAWN AVE
# - - - - JFK BLVD + DWIGHT ST
# - - JFK BLVD + AUDUBON AVE
# - - JFK BLVD + BAYVIEW AVENUE
# - - JFK BLVD + BROADMAN PKWY
# - - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + EGE AVE
# - - JFK BLVD + BOYD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - JFK BLVD + CLINTON AVE
# - JFK BLVD + COMMUNIPAW AVE
# - - JFK BLVD + BENTLEY AVE
# - - - - JFK BLVD + KENSINGTON AVE
# - JFK BLVD + JEWETT AVE
# - - JFK BLVD + DUNCAN AVE
# - - - - JFK BLVD + MONTGOMERY ST
# - - JFK BLVD + GLENWOOD AVE
# - - JFK BLVD + STUYVESANT AVE
# - - - - JFK BLVD + SIP AVE
# - SIP AVE + TONNELLE AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - HOBOKEN AVE + SUMMIT AVE
# - - CENTRAL AVE + HOBOKEN AVE
# - - CENTRAL AVE + SAINT PAULS AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + RESERVOIR AVE
# CENTRAL AVE + BOORAEM AVE
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + FRANKLIN ST
# - CENTRAL AVE + HUTTON ST
# CENTRAL AVE + GRIFFITH ST
# - CENTRAL AVE + BOWERS ST
# CENTRAL AVE + CHARLES ST
# CENTRAL AVE + SOUTH ST
# CENTRAL AVE + CONGRESS ST
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + PALISADE AVE
# - CONGRESS ST HBLR STATION
# - S WING VIADUCT + PATERSON PLANK ROAD
# - - - - - - - - - - WILLOW AVE + 15TH ST
# WILLOW AVE + 19TH ST
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - PORT AUTHORITY BUS TERMINAL + EAST END ARRIVAL

# %% [markdown]
# # my modified

# %%
# what uses it (insert into db in original script)

# %%
# my modified

import os
import datetime
import xml.etree.ElementTree

# API like: https://github.com/harperreed/transitapi/wiki/Unofficial-Bustracker-API

_sources = {
  'nj': 'http://mybusnow.njtransit.com/bustime/map/'
}

_api = {
  'all_buses': 'getBusesForRouteAll.jsp',
  'routes': 'getRoutePoints.jsp',
  'pattern_points': 'getPatternPoints.jsp',
  'stop_predictions': 'getStopPredictions.jsp',
  'bus_predictions': 'getBusPredictions.jsp',
  'buses_for_route': 'getBusesForRoute.jsp',
  'schedules': 'schedules.jsp',
  'time_and_temp': 'getTimeAndTemp.jsp',
  'route_directions_xml':  'routeDirectionStopAsXML',
}

# parsers done for all_buses, routes, stop_predictions
# ignored: time_and_temp
# not available / not fully documented: schedules (not sure what the right kwargs are, agency=1 & route=87 ?)


def _gen_command(source, func, **kwargs):
    result = _sources[source] + _api[func]
    params = ''
    for k, v in kwargs.items():
        params = params + k + '=' + str(v) + '&'
    if params:
        result += '?' + params[:-1]
    return result

def _cond_get_single(tree, key, default=''):
    res = tree.find(key)
    if res is not None:
        return res.text 
    return default

class KeyValueData:
    def __init__(self, **kwargs):
        self.name = 'KeyValueData'
        for k, v in kwargs.items():
            setattr(self, k, v)

    def add_kv(self, key, value):
        setattr(self, key, value)

    def __repr__(self):
        line = []
        for prop, value in vars(self).iteritems():
            line.append((prop, value))
        line.sort(key=lambda x: x[0])
        out_string = ' '.join([k + '=' + str(v) for k, v in line])
        return self.name + '[%s]' % out_string

class Route(KeyValueData):

    class Path(KeyValueData):
        def __init__(self):
            KeyValueData.__init__(self)
            self.name = 'Path'
            self.points = []
            self.id = ''
            self.d = ''
            self.dd = ''

    class Point:
        def __init__(self):
            self.lat = ''
            self.lon = ''
            self.d = ''

    class Stop:
        def __init__(self):
            self.identity = ''
            self.st = ''
            self.lat = ''
            self.lon = ''
            self.d = ''

    def __init__(self):
        KeyValueData.__init__(self)
        self.name = 'route'
        self.identity = ''
        self.paths = []


def parse_route_xml(data):

    routes = list()

    route = Route()

    e = xml.etree.ElementTree.fromstring(data)
    for child in e.getchildren():

        if len(child.getchildren()) == 0:
            if child.tag == 'id':
                route.identity = child.text
            else:
                route.add_kv(child.tag, child.text)

        if child.tag == 'pas':

            for pa in child.findall('pa'):

                path = Route.Path()

                for path_child in pa.getchildren():
                    if len(path_child.getchildren()) == 0:
                        if path_child.tag == 'id':
                            path.id = path_child.text
                        elif path_child.tag == 'd':
                            path.d = path_child.text
                        elif path_child.tag == 'dd':
                            path.dd = path_child.text
                        else:
                            path.add_kv(path_child.tag, path_child.text)
                    elif path_child.tag == 'pt':
                        pt = path_child
                        stop = False
                        for bs in pt.findall('bs'):
                            stop = True
                            _stop_id = _cond_get_single(bs, 'id')
                            _stop_st = _cond_get_single(bs, 'st')
                            break

                        p = None
                        if not stop:
                            p = Route.Point()
                        else:
                            p = Route.Stop()
                            p.identity = _stop_id
                            p.st = _stop_st

                        p.d = path.d
                        p.lat = _cond_get_single(pt, 'lat')
                        p.lon = _cond_get_single(pt, 'lon')

                        path.points.append(p) # <------ dont append to same list each time

                route.paths.append(path)

                routes.append(route.paths) # is this the change that broke stopwatcher? used to just be routes.append (route)
                # how can i change the waypoint map thing so this doesnt have to change, or change stopwatcher...

            break

    return routes

def get_xml_data(source, function, **kwargs):
    import urllib2
    data = urllib2.urlopen(_gen_command(source, function, **kwargs)).read()
    return data

# %%
# what it outputs
paths=parse_route_xml(get_xml_data(source, 'routes', route=route_report))
paths
# Out:
# /Users/anthonytownsend/anaconda2/envs/buswatcher/lib/python2.7/site-packages/ipykernel/__main__.py
d1c830>, <__main__.Point instance at 0x10cd1c878>, <__main__.Point instance at 0x10cd1c8c0>, <__main__.Point instance at 0x10cd1c908>, <__main__.Stop instance at 0x10cd1c950>, <__main__.Point instance at 0x10cd1c998>, <__main__.Stop instance at 0x10cd1c9e0>, <__main__.Point instance at 0x10cd1ca28>, <__main__.Point instance at 0x10cd1ca70>, <__main__.Point instance at 0x10cd1cab8>, <__main__.Point instance at 0x10cd1cb00>, <__main__.Stop instance at 0x10cd1cb48>, <__main__.Point instance at 0x10cd1cb90>, <__main__.Point instance at 0x10cd1cbd8>, <__main__.Stop instance at 0x10cd1cc20>, <__main__.Point instance at 0x10cd1cc68>, <__main__.Point instance at 0x10cd1ccb0>, <__main__.Stop instance at 0x10cd1ccf8>, <__main__.Point instance at 0x10cd1cd40>, <__main__.Point instance at 0x10cd1cd88>, <__main__.Stop instance at 0x10cd1cdd0>, <__main__.Point instance at 0x10cd1ce18>, <__main__.Point instance at 0x10cd1ce60>, <__main__.Stop instance at 0x10cd1cea8>, <__main__.Point instance at 0x10cd1cef0>, <__main__.Point instance at 0x10cd1cf38>, <__main__.Stop instance at 0x10cd1cf80>, <__main__.Point instance at 0x10cd1cfc8>, <__main__.Stop instance at 0x10cd1c050>, <__main__.Point instance at 0x10cd21098>, < ...

# %%
print "number of paths", len(paths)
for p in paths:
    for x in p:
        print "number of points", len(x.points)
        for i in x.points:
            if isinstance(i, Route.Stop):
                print i.st
            else:
                print '-',
# Out:
# number of paths 2
# number of points 241
# PORT AUTHORITY BUS TERMINAL
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - WILLOW AVE + 19TH ST
# - - - - WILLOW AVE + 15TH ST
# CONGRESS ST + PALISADE AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + CENTRAL AVE
# - - CENTRAL AVE + SOUTH ST
# CENTRAL AVE + THORNE ST
# CENTRAL AVE + BOWERS ST
# CENTRAL AVE + GRIFFITH ST
# CENTRAL AVE + HUTTON ST
# CENTRAL AVE + SHERMAN PL
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + BOOREAM AVE
# CENTRAL AVE + PERSHING PLAZA
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + LAIDLAW AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + SAINT PAULS AVE
# - CENTRAL AVE + HOBOKEN AVE
# - HOBOKEN AVE + SUMMIT AVE
# - SUMMIT AVE + PAVONIA AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - - - - - - - - - - - SIP AVE + TONNELLE AVE
# - JFK BLVD + SIP AVE
# - - - - JFK BLVD + STUYVESANT AVE
# - JFK BLVD + HIGHLAND AVE
# - JFK BLVD + MONTGOMERY ST
# - - - - - - JFK BLVD + DUNCAN AVE
# - - JFK BLVD + KENSINGTON AVE
# - - JFK BLVD + BELMONT AVENUE
# - JFK BLVD + BENTLEY AVE
# - - - JFK BLVD + COMMUNIPAW AVE
# - JFK BLVD + OXFORD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - - JFK BLVD + BOYD AVE
# - JFK BLVD + EGE AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + BROADMAN PKWY
# JFK BLVD + BAYVIEW AVE
# JFK BLVD + AUDUBON AVE
# JFK BLVD + STEGMAN PKWY
# - - JFK BLVD + VAN HOUTEN AVE
# - - - - - - JFK BLVD + WOODLAWN AVE
# - - JFK BLVD + VAN NOSTRAND AVE
# - - - - JFK BLVD + WADE ST
# - JFK BLVD + MCADOO AVENUE
# - - - JFK BLVD + DANFORTH AVE
# - JFK BLVD + GREENVILLE AVE
# - - - JFK BLVD + PEARSALL AVE
# - JFK BLVD + WINFIELD AVE
# - JFK BLVD + GATES AVE
# JFK BLVD + PAMRAPO AVE
# - - - - JFK BLVD + 63RD ST
# JFK BLVD + 57TH ST
# - JFK BLVD + 54TH ST
# - JFK BLVD + 52ND ST
# - JFK BLVD + 48TH ST
# JFK BLVD + 46TH ST
# JFK BLVD + 44TH ST
# JFK BLVD + 42ND ST
# JFK BLVD + DILLON DR
# - JFK BLVD + 37TH ST
# - - - - - - JFK BLVD + 35TH ST
# JFK BLVD + 33RD ST
# - - JFK BLVD + 30TH ST
# - JFK BLVD + 27TH ST
# JFK BLVD + 25TH ST
# JFK BLVD + 23RD ST
# JFK BLVD + 19TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 8TH ST
# - - - - - - JFK BLVD + W 6TH STREET
# - - JFK BLVD + W 4TH STREET
# JFK BLVD + 2ND ST
# number of points 226
# JFK BLVD + 3RD ST
# - JFK BLVD + 4TH ST
# - - - - JFK BLVD + W 7TH STREET
# - - - - - - JFK BLVD + 8TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 14TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + ANDREW ST
# JFK BLVD + 19TH ST
# JFK BLVD + 21ST ST
# JFK BLVD + 23RD ST
# JFK BLVD + 27TH ST
# JFK BLVD + 30TH ST
# JFK BLVD + 32ND ST
# JFK BLVD + 34TH ST
# - - - - - - - - JFK BLVD + 38 TH ST
# JFK BLVD + 39TH ST
# JFK BLVD + DELVIN DR
# JFK BLVD + 44TH ST
# JFK BLVD + 48TH ST
# JFK BLVD + 50TH ST
# JFK BLVD + 52ND ST
# JFK BLVD + 54TH ST
# JFK BLVD + 57TH ST
# JFK BLVD + 58TH ST
# - - JFK BLVD + 63RD ST
# JFK BLVD + GATES AVE
# JFK BLVD + WINFIELD AVE
# JFK BLVD + PEARSALL AVE
# - - - - JFK BLVD + GREENVILLE AVE
# - JFK BLVD + DANFORTH AVE
# - - JFK BLVD + MCADOO AVE
# - - JFK BLVD + WADE ST
# - - - - JFK BLVD + FOWLER AVE
# - JFK BLVD + WOODLAWN AVE
# - - - - JFK BLVD + DWIGHT ST
# - - JFK BLVD + AUDUBON AVE
# - - JFK BLVD + BAYVIEW AVENUE
# - - JFK BLVD + BROADMAN PKWY
# - - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + EGE AVE
# - - JFK BLVD + BOYD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - JFK BLVD + CLINTON AVE
# - JFK BLVD + COMMUNIPAW AVE
# - - JFK BLVD + BENTLEY AVE
# - - - - JFK BLVD + KENSINGTON AVE
# - JFK BLVD + JEWETT AVE
# - - JFK BLVD + DUNCAN AVE
# - - - - JFK BLVD + MONTGOMERY ST
# - - JFK BLVD + GLENWOOD AVE
# - - JFK BLVD + STUYVESANT AVE
# - - - - JFK BLVD + SIP AVE
# - SIP AVE + TONNELLE AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - HOBOKEN AVE + SUMMIT AVE
# - - CENTRAL AVE + HOBOKEN AVE
# - - CENTRAL AVE + SAINT PAULS AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + RESERVOIR AVE
# CENTRAL AVE + BOORAEM AVE
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + FRANKLIN ST
# - CENTRAL AVE + HUTTON ST
# CENTRAL AVE + GRIFFITH ST
# - CENTRAL AVE + BOWERS ST
# CENTRAL AVE + CHARLES ST
# CENTRAL AVE + SOUTH ST
# CENTRAL AVE + CONGRESS ST
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + PALISADE AVE
# - CONGRESS ST HBLR STATION
# - S WING VIADUCT + PATERSON PLANK ROAD
# - - - - - - - - - - WILLOW AVE + 15TH ST
# WILLOW AVE + 19TH ST
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - PORT AUTHORITY BUS TERMINAL + EAST END ARRIVAL
# number of points 241
# PORT AUTHORITY BUS TERMINAL
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - WILLOW AVE + 19TH ST
# - - - - WILLOW AVE + 15TH ST
# CONGRESS ST + PALISADE AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + CENTRAL AVE
# - - CENTRAL AVE + SOUTH ST
# CENTRAL AVE + THORNE ST
# CENTRAL AVE + BOWERS ST
# CENTRAL AVE + GRIFFITH ST
# CENTRAL AVE + HUTTON ST
# CENTRAL AVE + SHERMAN PL
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + BOOREAM AVE
# CENTRAL AVE + PERSHING PLAZA
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + LAIDLAW AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + SAINT PAULS AVE
# - CENTRAL AVE + HOBOKEN AVE
# - HOBOKEN AVE + SUMMIT AVE
# - SUMMIT AVE + PAVONIA AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - - - - - - - - - - - SIP AVE + TONNELLE AVE
# - JFK BLVD + SIP AVE
# - - - - JFK BLVD + STUYVESANT AVE
# - JFK BLVD + HIGHLAND AVE
# - JFK BLVD + MONTGOMERY ST
# - - - - - - JFK BLVD + DUNCAN AVE
# - - JFK BLVD + KENSINGTON AVE
# - - JFK BLVD + BELMONT AVENUE
# - JFK BLVD + BENTLEY AVE
# - - - JFK BLVD + COMMUNIPAW AVE
# - JFK BLVD + OXFORD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - - JFK BLVD + BOYD AVE
# - JFK BLVD + EGE AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + BROADMAN PKWY
# JFK BLVD + BAYVIEW AVE
# JFK BLVD + AUDUBON AVE
# JFK BLVD + STEGMAN PKWY
# - - JFK BLVD + VAN HOUTEN AVE
# - - - - - - JFK BLVD + WOODLAWN AVE
# - - JFK BLVD + VAN NOSTRAND AVE
# - - - - JFK BLVD + WADE ST
# - JFK BLVD + MCADOO AVENUE
# - - - JFK BLVD + DANFORTH AVE
# - JFK BLVD + GREENVILLE AVE
# - - - JFK BLVD + PEARSALL AVE
# - JFK BLVD + WINFIELD AVE
# - JFK BLVD + GATES AVE
# JFK BLVD + PAMRAPO AVE
# - - - - JFK BLVD + 63RD ST
# JFK BLVD + 57TH ST
# - JFK BLVD + 54TH ST
# - JFK BLVD + 52ND ST
# - JFK BLVD + 48TH ST
# JFK BLVD + 46TH ST
# JFK BLVD + 44TH ST
# JFK BLVD + 42ND ST
# JFK BLVD + DILLON DR
# - JFK BLVD + 37TH ST
# - - - - - - JFK BLVD + 35TH ST
# JFK BLVD + 33RD ST
# - - JFK BLVD + 30TH ST
# - JFK BLVD + 27TH ST
# JFK BLVD + 25TH ST
# JFK BLVD + 23RD ST
# JFK BLVD + 19TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 8TH ST
# - - - - - - JFK BLVD + W 6TH STREET
# - - JFK BLVD + W 4TH STREET
# JFK BLVD + 2ND ST
# number of points 226
# JFK BLVD + 3RD ST
# - JFK BLVD + 4TH ST
# - - - - JFK BLVD + W 7TH STREET
# - - - - - - JFK BLVD + 8TH ST
# JFK BLVD + 10TH ST
# JFK BLVD + 12TH ST
# JFK BLVD + 14TH ST
# JFK BLVD + 16TH ST
# JFK BLVD + ANDREW ST
# JFK BLVD + 19TH ST
# JFK BLVD + 21ST ST
# JFK BLVD + 23RD ST
# JFK BLVD + 27TH ST
# JFK BLVD + 30TH ST
# JFK BLVD + 32ND ST
# JFK BLVD + 34TH ST
# - - - - - - - - JFK BLVD + 38 TH ST
# JFK BLVD + 39TH ST
# JFK BLVD + DELVIN DR
# JFK BLVD + 44TH ST
# JFK BLVD + 48TH ST
# JFK BLVD + 50TH ST
# JFK BLVD + 52ND ST
# JFK BLVD + 54TH ST
# JFK BLVD + 57TH ST
# JFK BLVD + 58TH ST
# - - JFK BLVD + 63RD ST
# JFK BLVD + GATES AVE
# JFK BLVD + WINFIELD AVE
# JFK BLVD + PEARSALL AVE
# - - - - JFK BLVD + GREENVILLE AVE
# - JFK BLVD + DANFORTH AVE
# - - JFK BLVD + MCADOO AVE
# - - JFK BLVD + WADE ST
# - - - - JFK BLVD + FOWLER AVE
# - JFK BLVD + WOODLAWN AVE
# - - - - JFK BLVD + DWIGHT ST
# - - JFK BLVD + AUDUBON AVE
# - - JFK BLVD + BAYVIEW AVENUE
# - - JFK BLVD + BROADMAN PKWY
# - - JFK BLVD + CLAREMONT AVE
# - - JFK BLVD + MORTON PL
# - JFK BLVD + EGE AVE
# - - JFK BLVD + BOYD AVE
# - - - - JFK BLVD + CLENDENNY AVE
# - - JFK BLVD + CLINTON AVE
# - JFK BLVD + COMMUNIPAW AVE
# - - JFK BLVD + BENTLEY AVE
# - - - - JFK BLVD + KENSINGTON AVE
# - JFK BLVD + JEWETT AVE
# - - JFK BLVD + DUNCAN AVE
# - - - - JFK BLVD + MONTGOMERY ST
# - - JFK BLVD + GLENWOOD AVE
# - - JFK BLVD + STUYVESANT AVE
# - - - - JFK BLVD + SIP AVE
# - SIP AVE + TONNELLE AVE
# - - - JOURNAL SQUARE LANE D
# - - - - - - HOBOKEN AVE + SUMMIT AVE
# - - CENTRAL AVE + HOBOKEN AVE
# - - CENTRAL AVE + SAINT PAULS AVE
# CENTRAL AVE + BEACON AVE
# CENTRAL AVE + WAVERLY ST
# CENTRAL AVE + RESERVOIR AVE
# CENTRAL AVE + BOORAEM AVE
# CENTRAL AVE + MANHATTAN AVE
# CENTRAL AVE + FRANKLIN ST
# - CENTRAL AVE + HUTTON ST
# CENTRAL AVE + GRIFFITH ST
# - CENTRAL AVE + BOWERS ST
# CENTRAL AVE + CHARLES ST
# CENTRAL AVE + SOUTH ST
# CENTRAL AVE + CONGRESS ST
# CONGRESS ST + HANCOCK AVE
# CONGRESS ST + WEBSTER AVE
# CONGRESS ST + PALISADE AVE
# - CONGRESS ST HBLR STATION
# - S WING VIADUCT + PATERSON PLANK ROAD
# - - - - - - - - - - WILLOW AVE + 15TH ST
# WILLOW AVE + 19TH ST
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - PORT AUTHORITY BUS TERMINAL + EAST END ARRIVAL

# %%
# what uses it (the waypoints map notebook)
