# %%
# new data structure for STOPWATCHER
# build up tables BY VEHICLE - a history of observations of each vehicle
# then can go and reconstruct unique history for each VEHICLE, based on last observeration before it STOPPED APPROACHING each stop in the _stoplist_

# %%
# relative import
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from src.buses.reportcard_helpers import *

# %%
import time
import pandas as pd

# %%
def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = int((te - ts) * 1000)
        else:
            print '%r  %2.2f ms' % \
                  (method.__name__, (te - ts) * 1000)
        return result
    return timed

# %%
source = 'nj'
route = 119

# %%
(conn, db) = db_setup(route)

# %%
# only get buses APPROACHING A STOP
# arrival_query = ('SELECT * FROM stop_predictions \
#                WHERE (rd = %s AND pt = "APPROACHING") \
#                ORDER BY timestamp;' % route)
arrival_query = ('SELECT * FROM stop_predictions;')

# %%
df = pd.read_sql_query(arrival_query, conn)
df
# Out:
#           pkey cars consist                                                 fd  m            name           pt   rd   rn scheduled stop_id                      stop_name     v                   timestamp
# 0            1               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            8  119  119     false   26229    PORT AUTHORITY BUS TERMINAL  6200  2018-06-07 14:14:04.349723
# 1            2               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           16  119  119     false   21854           WILLOW AVE + 19TH ST  6200  2018-06-07 14:14:04.471519
# 2            3               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           17  119  119     false   20523           WILLOW AVE + 15TH ST  6200  2018-06-07 14:14:04.521519
# 3            4               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           22  119  119     false   20668     CONGRESS ST + PALISADE AVE  6200  2018-06-07 14:14:04.569904
# 4            5               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           22  119  119     false   20670      CONGRESS ST + WEBSTER AVE  6200  2018-06-07 14:14:04.620028
# 5            6               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           23  119  119     false   20671      CONGRESS ST + HANCOCK AVE  6200  2018-06-07 14:14:04.670139
# 6            7               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           24  119  119     false   20672      CONGRESS ST + CENTRAL AVE  6200  2018-06-07 14:14:04.719928
# 7            8               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           25  119  119     false   20629         CENTRAL AVE + SOUTH ST  6200  2018-06-07 14:14:04.763751
# 8            9               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           25  119  119     false   20630        CENTRAL AVE + THORNE ST  6200  2018-06-07 14:14:04.817999
# 9           10               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           26  119  119     false   20631        CENTRAL AVE + BOWERS ST  6200  2018-06-07 14:14:04.865516
# 10          11               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           27  119  119     false   20632      CENTRAL AVE + GRIFFITH ST  6200  2018-06-07 14:14:04.926103
# 11          12               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction  APPROACHING  119  119     false   20633        CENTRAL AVE + HUTTON ST  6021  2018-06-07 14:14:04.978651
# 12          13               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           27  119  119     false   20633        CENTRAL AVE + HUTTON ST  6200  2018-06-07 14:14:04.978651
# 13          14               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction  APPROACHING  119  119     false   20634       CENTRAL AVE + SHERMAN PL  6021  2018-06-07 14:14:05.028441
# 14          15               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           28  119  119     false   20634       CENTRAL AVE + SHERMAN PL  6200  2018-06-07 14:14:05.028441
# 15          16               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            1  119  119     false   20635    CENTRAL AVE + MANHATTAN AVE  6021  2018-06-07 14:14:05.086384
# 16          17               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           29  119  119     false   20635    CENTRAL AVE + MANHATTAN AVE  6200  2018-06-07 14:14:05.086384
# 17          18               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            2  119  119     false   20636      CENTRAL AVE + BOOREAM AVE  6021  2018-06-07 14:14:05.146186
# 18          19               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            3  119  119     false   20637   CENTRAL AVE + PERSHING PLAZA  6021  2018-06-07 14:14:05.197528
# 19          20               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            3  119  119     false   20638       CENTRAL AVE + WAVERLY ST  6021  2018-06-07 14:14:05.252194
# 20          21               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            4  119  119     false   20639      CENTRAL AVE + LAIDLAW AVE  6021  2018-06-07 14:14:05.300860
# 21          22               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            5  119  119     false   20640       CENTRAL AVE + BEACON AVE  6021  2018-06-07 14:14:05.350017
# 22          23               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            6  119  119     false   20641  CENTRAL AVE + SAINT PAULS AVE  6021  2018-06-07 14:14:05.396762
# 23          24               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            7  119  119     false   20642      CENTRAL AVE + HOBOKEN AVE  6021  2018-06-07 14:14:05.446828
# 24          25               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            8  119  119     false   20784       HOBOKEN AVE + SUMMIT AVE  6021  2018-06-07 14:14:05.515617
# 25          26               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            9  119  119     false   21124       SUMMIT AVE + PAVONIA AVE  6021  2018-06-07 14:14:05.605438
# 26          27                                                    119 NEW YORK  1  StopPrediction            4  119  119     false   31732          JOURNAL SQUARE LANE D  6022  2018-06-07 14:14:05.643735
# 27          28               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           12  119  119     false   31732          JOURNAL SQUARE LANE D  6021  2018-06-07 14:14:05.643735
# 28          29               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           15  119  119     false   21093         SIP AVE + TONNELLE AVE  6021  2018-06-07 14:14:05.685094
# 29          30               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           16  119  119     false   20852             JFK BLVD + SIP AVE  6021  2018-06-07 14:14:05.727429
# ...        ...  ...     ...                                                ... ..             ...          ...  ...  ...       ...     ...                            ...   ...                         ...
# 609889  609890               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           14  119  119     false   20410             JFK BLVD + 54TH ST  6190  2018-06-11 21:14:11.942767
# 609890  609891               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           14  119  119     false   20411             JFK BLVD + 52ND ST  6190  2018-06-11 21:14:11.992217
# 609891  609892               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           15  119  119     false   20412             JFK BLVD + 48TH ST  6190  2018-06-11 21:14:12.045036
# 609892  609893               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           16  119  119     false   20413             JFK BLVD + 46TH ST  6190  2018-06-11 21:14:12.096011
# 609893  609894               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           16  119  119     false   20414             JFK BLVD + 44TH ST  6190  2018-06-11 21:14:12.138806
# 609894  609895               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           16  119  119     false   20415             JFK BLVD + 42ND ST  6190  2018-06-11 21:14:12.194309
# 609895  609896               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           17  119  119     false   20416           JFK BLVD + DILLON DR  6190  2018-06-11 21:14:12.245522
# 609896  609897               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           17  119  119     false   20417             JFK BLVD + 37TH ST  6190  2018-06-11 21:14:12.313951
# 609897  609898               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           18  119  119     false   20418             JFK BLVD + 35TH ST  6190  2018-06-11 21:14:12.360547
# 609898  609899               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           19  119  119     false   20419             JFK BLVD + 33RD ST  6190  2018-06-11 21:14:12.411078
# 609899  609900               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           20  119  119     false   20420             JFK BLVD + 30TH ST  6190  2018-06-11 21:14:12.461206
# 609900  609901               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           20  119  119     false   20421             JFK BLVD + 27TH ST  6190  2018-06-11 21:14:12.511971
# 609901  609902               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction  APPROACHING  119  119     false   20422             JFK BLVD + 25TH ST  6013  2018-06-11 21:14:12.592844
# 609902  609903               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           21  119  119     false   20422             JFK BLVD + 25TH ST  6190  2018-06-11 21:14:12.592844
# 609903  609904               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction  APPROACHING  119  119     false   20423             JFK BLVD + 23RD ST  6013  2018-06-11 21:14:12.637255
# 609904  609905               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           21  119  119     false   20423             JFK BLVD + 23RD ST  6190  2018-06-11 21:14:12.637255
# 609905  609906               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            1  119  119     false   20424             JFK BLVD + 19TH ST  6013  2018-06-11 21:14:12.691006
# 609906  609907               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           22  119  119     false   20424             JFK BLVD + 19TH ST  6190  2018-06-11 21:14:12.691006
# 609907  609908               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            2  119  119     false   20425             JFK BLVD + 16TH ST  6013  2018-06-11 21:14:12.744461
# 609908  609909               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           22  119  119     false   20425             JFK BLVD + 16TH ST  6190  2018-06-11 21:14:12.744461
# 609909  609910               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            2  119  119     false   20426             JFK BLVD + 12TH ST  6013  2018-06-11 21:14:12.796832
# 609910  609911               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           23  119  119     false   20426             JFK BLVD + 12TH ST  6190  2018-06-11 21:14:12.796832
# 609911  609912               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            3  119  119     false   20427             JFK BLVD + 10TH ST  6013  2018-06-11 21:14:13.384603
# 609912  609913               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           24  119  119     false   20427             JFK BLVD + 10TH ST  6190  2018-06-11 21:14:13.384603
# 609913  609914               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            3  119  119     false   20428              JFK BLVD + 8TH ST  6013  2018-06-11 21:14:13.497684
# 609914  609915               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           24  119  119     false   20428              JFK BLVD + 8TH ST  6190  2018-06-11 21:14:13.497684
# 609915  609916               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            4  119  119     false   31595        JFK BLVD + W 6TH STREET  6013  2018-06-11 21:14:13.583968
# 609916  609917               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           25  119  119     false   31595        JFK BLVD + W 6TH STREET  6190  2018-06-11 21:14:13.583968
# 609917  609918               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction            5  119  119     false   31596        JFK BLVD + W 4TH STREET  6013  2018-06-11 21:14:13.705581
# 609918  609919               119 JERSEY CITY VIA CENTRAL BAYOONNE VIA JFK BLVD  1  StopPrediction           25  119  119     false   31596        JFK BLVD + W 4TH STREET  6190  2018-06-11 21:14:13.705581
#
# [609919 rows x 14 columns]

# %%
df = timestamp_fix(df)
df.head(5)

# %%
# 1 group all arrival predictions by unique vehicle-stop combinations
df.groupby(['v','stop_id'])

# 2 gets the keys for unique vehicle-stop combinations
# a list of tuples
# [(u'5403', u'20640'), (u'5704', u'20933'), .....

keys = df.groupby(['v','stop_id']).groups.keys()

# %%
@timeit
def make_history(df):

    # THIS IS WAYYYYYYY FASTER !!!

    # history data structure = assign every row in df to a dict keyed to unique vehicle/stop_id instance
    # {
    #  5403_20640: [row1, row15, ...]
    #  5704_20933: [row2, row37, ...]    
    # }

    from collections import defaultdict
    history = defaultdict(list)

    for index,row in df.iterrows():
        key = row['v'] + '_' + row['stop_id']
        history[key].append(row)

    # sort them and slice them

    keepers = defaultdict(list)
    discards = defaultdict(list)

    # iterate over the dict
    for key_copy, arrivals in history.iteritems():

        # sort each arrival list
        arrivals.sort(key=lambda x: x.timestamp)

        #
        #
        # NEED TO GROUPBY ONES THAT HAVE THE SAME GENERAL ARRIVAL WINDOW
        #
        # PROBLEM WITH BELOW IS THAT IT DOESNT WORK WHEN WE HAVE A FULL HISTORY
        # BECAUSE IT DOESNT DETECT EVENTS? e.g. VEHICLE-STOP COMBINATIONS ARE NOT UNIQUE FOR MORE THAN A FEW HOURS
        #
        #   

        # put last row in keepers
        keepers[key_copy].append(arrivals[-1])

        # put everything else in discards
        discards[key_copy].append(arrivals[:-1])
        
        return keepers,discards

# %%
# this isnt working now.... only returning 1?

# %%
(keepers,discards) = make_history(df)

# %%
print keepers

# %%
print discards

# %%
# 1. NEW STOPWATCHER V1 - single stop frequency of service

# use the new stopwatcher data model and drill down to an appraoches table for unique (stop,route) listing all APPROACHING observations (an 'approach') in history. then either excerpt a separate table or set a flag on the last approach in each sequence. that timestamp is then treated as the actual arrival time.

# then use that table of arrivals to calculate report card stats and visualizations

# ***THIS IS KIND OF A HACKY WAY OF LOCALIZING THE BUS TO THE STOP (but it works, letting CleverDevices do the heavy lifting of interpolation)
