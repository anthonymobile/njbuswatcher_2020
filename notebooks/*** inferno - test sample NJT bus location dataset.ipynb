# %%
# relative import
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

from src.buses.reportcard_helpers import *

# %%
db = BusDB.MySQL('buses', 'buswatcher', 'njtransit','192.168.1.200')

# %%
stop_id = 0
route = 87
v = 0

# %%
query = "SELECT * FROM positions LIMIT 10"

# %%
db.fetch_records(query)
# Out:
# [(1,
#   40.66814,
#   -74.376962,
#   u'',
#   u'2547',
#   u'#FFFFFF',
#   u'',
#   u'',
#   u'East Bound',
#   u'East Bound',
#   u'ENE',
#   u'N/A',
#   u'8225',
#   u'1',
#   u'356060',
#   u'N/A',
#   u'',
#   u'0',
#   u'PI',
#   u'',
#   u'PI',
#   u'',
#   u'350',
#   u'350',
#   u'0114',
#   u'2018-05-31 19:18:39.264978'),
#  (2,
#   40.169895,
#   -74.238743,
#   u'',
#   u'MAN',
#   u'#999933',
#   u'',
#   u'',
#   u'North West Bound',
#   u'North West Bound',
#   u'NNW',
#   u'139 NEW YORK VIA FREEHOLD MALL/CENTER',
#   u'8224',
#   u'1',
#   u'506120',
#   u'New York',
#   u'',
#   u'9426',
#   u'139',
#   u'',
#   u'139',
#   u'',
#   u'MAN',
#   u'046',
#   u'0136',
#   u'2018-05-31 19:18:39.264978'),
#  (3,
#   40.756152,
#   -73.991802,
#   u'',
#   u'2442',
#   u'#ff0099',
#   u'',
#   u'',
#   u'West Bound',
#   u'West Bound',
#   u'W',
#   u'112 NEW YORK',
#   u'8226',
#   u'1',
#   u'537250',
#   u'New York',
#   u'',
#   u'1793',
#   u'112',
#   u'',
# ...

# %%
# fetch records and rewrite to a format that can be ingested into inferno... 
# for mapping against the GTFS file for stop inferring?
# https://github.com/Bus-Data-NYC/inferno

# need to migrate to postgres?
