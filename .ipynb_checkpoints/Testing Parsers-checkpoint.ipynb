# %%
import Buses

# %%
# routes
Buses.parse_route_xml(Buses.get_xml_data('nj', 'routes', route=126))
# Out:
# route[c=#003366 displayDesignator=126 identity=126 name=route nm=126 Hoboken - New York paths=[Path[d=New York dd=New York directionRtpiFeedName=None identity=19218 l=24023.0 name=Path points=[<Buses.Stop instance at 0x10c596ef0>, <Buses.Point instance at 0x10c596e18>, <Buses.Point instance at 0x10c5a11b8>, <Buses.Point instance at 0x10c5a1200>, <Buses.Stop instance at 0x10c5a1290>, <Buses.Stop instance at 0x10c5a1320>, <Buses.Stop instance at 0x10c5a13b0>, <Buses.Stop instance at 0x10c5a1440>, <Buses.Stop instance at 0x10c5a14d0>, <Buses.Stop instance at 0x10c5a1560>, <Buses.Point instance at 0x10c5a15f0>, <Buses.Stop instance at 0x10c5a1680>, <Buses.Point instance at 0x10c5a1710>, <Buses.Stop instance at 0x10c5a17a0>, <Buses.Point instance at 0x10c5a1830>, <Buses.Stop instance at 0x10c5a18c0>, <Buses.Stop instance at 0x10c5a1950>, <Buses.Point instance at 0x10c5a19e0>, <Buses.Point instance at 0x10c5a1a70>, <Buses.Point instance at 0x10c5a1b00>, <Buses.Point instance at 0x10c5a1b90
# ...

# %%
# routes
Buses.parse_stopprediction_xml(Buses.get_xml_data('nj', 'stop_predictions','?stop=30189'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2e9bf2ddd613> in <module>()
#       1 # routes
# ----> 2 Buses.parse_stopprediction_xml(Buses.get_xml_data('nj', 'stop_predictions?stop=30189'))
#
# /Users/anthonytownsend/Dropbox/Desktop/code/buswatcher/Buses.pyc in get_xml_data(source, function, **kwargs)
#     191 def get_xml_data(source, function, **kwargs):
#     192     import urllib2
# --> 193     data = urllib2.urlopen(_gen_command(source, function, **kwargs)).read()
#     194     return data
#     195
#
# /Users/anthonytownsend/Dropbox/Desktop/code/buswatcher/Buses.pyc in _gen_command(source, func, **kwargs)
#      27
#      28 def _gen_command(source, func, **kwargs):
# ---> 29     result = _sources[source] + _api[func]
#      30     params = ''
#      31     for k, v in kwargs.items():
#
# KeyError: 'stop_predictions?stop=30189'
